# %% [markdown]
# #### Cell 1 — Project root + imports

# %%
# --- Project Root Setup (run first in every notebook) ---
from pathlib import Path
import sys
root = Path("..").resolve()
sys.path.append(str(root / "src"))
print("Project root:", root)
# Out:
# Project root: /home/falasoul/notebooks/USD/AAI-590/Capstone/AAI-590-G3-ASL

# %% [markdown]
# #### Cell 2 — Load flattened JSON, compute top-100 glosses, save artifacts
# This builds stable label maps and a filtered JSON just for WLASL100.

# %%
import json, yaml
from collections import Counter

# Load config & flat JSON
with open(root / "configs" / "wlasl100.yaml", "r") as f:
    C = yaml.safe_load(f)
flat_path = root / "data" / "metadata" / "WLASL_flat.json"
data = json.load(open(flat_path))

# Count per-gloss frequency and pick top-K
top_k = C["wlasl"]["top_k"]
gloss_counts = Counter(d["gloss"] for d in data)
most_common = gloss_counts.most_common(top_k)

# Tie-break: frequency desc, then alphabetical asc for determinism
most_common_sorted = sorted(most_common, key=lambda x: (-x[1], x[0]))
top_glosses = [g for g, _ in most_common_sorted]

# Build label maps (stable)
gloss2idx = {g: i for i, g in enumerate(top_glosses)}
idx2gloss = {i: g for g, i in gloss2idx.items()}

# Filter instances to only top-100
wl100 = [d for d in data if d["gloss"] in gloss2idx]

# Save artifacts
meta_dir = root / "data" / "metadata"
meta_dir.mkdir(parents=True, exist_ok=True)
(json.dumps(top_glosses, indent=2))
with open(meta_dir / "wlasl100_glosses.txt", "w") as f:
    f.write("\n".join(top_glosses))
with open(meta_dir / "wlasl100_label_map.json", "w") as f:
    json.dump({"gloss2idx": gloss2idx, "idx2gloss": idx2gloss}, f, indent=2)
with open(meta_dir / "WLASL100_flat.json", "w") as f:
    json.dump(wl100, f, indent=2)

print(f"Top-{top_k} glosses saved to wlasl100_glosses.txt")
print(f"Label map saved to wlasl100_label_map.json")
print(f"WLASL100 instances: {len(wl100)}")
# Out:
# Top-100 glosses saved to wlasl100_glosses.txt
# Label map saved to wlasl100_label_map.json
# WLASL100 instances: 2038

# %% [markdown]
# #### Cell 3 — Quick sanity: counts per split for WLASL100

# %%
from collections import Counter, defaultdict

split_counts = Counter(d["split"] for d in wl100)
per_gloss = defaultdict(lambda: Counter())
for d in wl100:
    per_gloss[d["gloss"]][d["split"]] += 1

print("WLASL100 split counts:", dict(split_counts))
print("Examples per gloss (min/avg/max):",
      min(sum(c.values()) for c in per_gloss.values()),
      sum(sum(c.values()) for c in per_gloss.values())/len(per_gloss),
      max(sum(c.values()) for c in per_gloss.values()))
# Out:
# WLASL100 split counts: {'train': 1442, 'val': 338, 'test': 258}
# Examples per gloss (min/avg/max): 18 20.38 40

# %% [markdown]
# #### Cell 4 — Prepare download list + outputs
# We’ll download to data/raw/{video_id}.mp4, create a missing.txt, and remux non-mp4 inputs to mp4 if needed.

# %%
import os, subprocess, shutil
from tqdm import tqdm
from urllib.parse import urlparse

raw_dir = root / "data" / "raw"
raw_dir.mkdir(parents=True, exist_ok=True)
missing = []
downloaded = 0

def ensure_mp4(path_in: Path) -> Path:
    """
    If the downloaded file is not .mp4 or not H.264/AAC container,
    remux/re-encode to mp4 using ffmpeg (stream copy if possible).
    """
    if path_in.suffix.lower() == ".mp4":
        return path_in
    path_out = path_in.with_suffix(".mp4")
    cmd = ["ffmpeg", "-y", "-i", str(path_in), "-c", "copy", str(path_out)]
    try:
        subprocess.run(cmd, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        path_in.unlink(missing_ok=True)
        return path_out
    except subprocess.CalledProcessError:
        # fallback: re-encode to guaranteed mp4 (H.264 + AAC)
        cmd = ["ffmpeg", "-y", "-i", str(path_in), "-c:v", "libx264", "-c:a", "aac", "-movflags", "+faststart", str(path_out)]
        subprocess.run(cmd, check=True)
        path_in.unlink(missing_ok=True)
        return path_out

def download_one(url: str, vid: str) -> bool:
    # target path (without extension yet)
    target = raw_dir / f"{vid}.mp4"
    if target.exists():
        return True
    # temp path (let yt-dlp choose extension)
    tmp = raw_dir / f"{vid}.%(ext)s"
    cmd = [
        "yt-dlp",
        "-o", str(tmp),
        "-f", "mp4/best",   # prefer mp4; fallback to best
        url
    ]
    try:
        subprocess.run(cmd, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        # Find the actual file that was saved (match vid.*)
        candidates = list(raw_dir.glob(f"{vid}.*"))
        if not candidates:
            return False
        final_path = ensure_mp4(candidates[0])
        return final_path.exists()
    except subprocess.CalledProcessError:
        return False

# Build a unique set of (video_id, url) to avoid duplicates
pairs = {}
for d in wl100:
    vid, url = d["video_id"], d["url"]
    if vid and url:
        pairs[vid] = url

print(f"Prepared {len(pairs)} unique videos to download.")
# Out:
# Prepared 2038 unique videos to download.

# %% [markdown]
# #### Cell 5 — Download with retries (YouTube + direct HTTP both work in yt-dlp)

# %%
import sys, subprocess, shutil

# Check if yt-dlp exists in PATH
print("yt-dlp path:", shutil.which("yt-dlp"))

# Install or upgrade inside current ai-env if missing
if shutil.which("yt-dlp") is None:
    subprocess.run([sys.executable, "-m", "pip", "install", "--upgrade", "yt-dlp"], check=True)

# Re-check
print("yt-dlp path after install:", shutil.which("yt-dlp"))
# Out:
# yt-dlp path: None
# Requirement already satisfied: yt-dlp in /home/falasoul/venvs/ai-env/lib/python3.11/site-packages (2025.10.22)
# yt-dlp path after install: None

# %%
# Preflight: fast reachability filter to avoid long stalls
from pathlib import Path
import json, yaml, sys, time
from urllib.parse import urlparse
import requests
from tqdm import tqdm

root = Path("..").resolve()
C = yaml.safe_load(open(root / "configs" / "wlasl100.yaml"))
meta = json.load(open(root / "data" / "metadata" / "WLASL100_flat.json"))

# Build unique (video_id -> url)
pairs = {}
for d in meta:
    vid, url = d.get("video_id"), d.get("url")
    if vid and url and vid not in pairs:
        pairs[vid] = url

# Domains we know are frequently down/slow — skip for now (we'll request these)
BLOCKLIST = {"www.aslpro.com"}  # add if you see repeated timeouts: {'aslsignbank.haskins.yale.edu', ...}

def host(url: str) -> str:
    try:
        return urlparse(url).netloc.lower()
    except Exception:
        return ""

# Quick HEAD probe with short timeout; we only need to know if host is responsive at all
def is_reachable(url: str, timeout=4):
    h = host(url)
    if h in BLOCKLIST:
        return False
    try:
        # some servers don't support HEAD; allow GET fallback
        r = requests.head(url, timeout=timeout, allow_redirects=True)
        if 200 <= r.status_code < 400:
            return True
        # retry with GET for HEAD-hostile servers
        r = requests.get(url, stream=True, timeout=timeout, allow_redirects=True)
        return 200 <= r.status_code < 400
    except Exception:
        return False

reachable, unreachable = {}, []

for vid, url in tqdm(pairs.items(), desc="Preflight reachability"):
    if is_reachable(url):
        reachable[vid] = url
    else:
        unreachable.append(vid)

meta_dir = root / "data" / "metadata"
meta_dir.mkdir(parents=True, exist_ok=True)
with open(meta_dir / "preflight_unreachable.txt", "w") as f:
    f.write("\n".join(unreachable))

print(f"Reachable: {len(reachable)} / {len(pairs)}")
print(f"Preflight unreachable saved to: {meta_dir / 'preflight_unreachable.txt'}")

# Use only reachable URLs for the heavy yt-dlp step:
pairs = reachable
# Out:
# Preflight reachability: 100%|██████████| 2038/2038 [09:38<00:00,  3.52it/s]
# Reachable: 1480 / 2038
# Preflight unreachable saved to: /home/falasoul/notebooks/USD/AAI-590/Capstone/AAI-590-G3-ASL/data/metadata/preflight_unreachable.txt

# %%
from yt_dlp import YoutubeDL
from pathlib import Path
import json, yaml, shutil, subprocess, sys
from time import sleep
from urllib.parse import urlparse, urlunparse
from tqdm import tqdm

root = Path("..").resolve()
with open(root / "configs" / "wlasl100.yaml", "r") as f:
    C = yaml.safe_load(f)

meta = json.load(open(root / "data" / "metadata" / "WLASL100_flat.json"))
raw_dir = root / "data" / "raw"
raw_dir.mkdir(parents=True, exist_ok=True)

# ---------- helpers ----------
def normalize_url(u: str) -> str:
    # Yale Signbank has TLS hostname mismatch; prefer http
    try:
        p = urlparse(u)
        host = (p.netloc or "").lower()
        if "aslsignbank.haskins.yale.edu" in host:
            p = p._replace(scheme="http")
            return urlunparse(p)
        return u
    except Exception:
        return u

def ensure_mp4(path_in: Path) -> Path:
    if path_in.suffix.lower() == ".mp4":
        return path_in
    dst = path_in.with_suffix(".mp4")
    ffmpeg = shutil.which("ffmpeg")
    if not ffmpeg:
        return path_in  # can't remux
    # try stream copy then re-encode
    try:
        subprocess.run(["ffmpeg","-y","-i",str(path_in),"-c","copy","-movflags","+faststart",str(dst)],
                       check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        path_in.unlink(missing_ok=True)
        return dst
    except subprocess.CalledProcessError:
        subprocess.run(["ffmpeg","-y","-i",str(path_in),"-c:v","libx264","-c:a","aac","-movflags","+faststart",str(dst)],
                       check=True)
        path_in.unlink(missing_ok=True)
        return dst

def is_youtube(url: str) -> bool:
    n = urlparse(url).netloc.lower()
    return "youtube.com" in n or "youtu.be" in n

# unique (video_id -> url)
pairs = {}
for d in meta:
    vid, url = d.get("video_id"), d.get("url")
    if vid and url and vid not in pairs:
        pairs[vid] = normalize_url(url)

ffmpeg_path = shutil.which("ffmpeg")
print("ffmpeg:", ffmpeg_path or "NOT FOUND (install with apt)")

# ---- NEW: filter to preflight reachable only (if file exists) ----
preflight_path = root / "data" / "metadata" / "preflight_unreachable.txt"
if preflight_path.exists():
    unreachable_ids = set(x.strip() for x in preflight_path.read_text().splitlines() if x.strip())
    before = len(pairs)
    pairs = {vid: url for vid, url in pairs.items() if vid not in unreachable_ids}
    print(f"Filtered out {before - len(pairs)} preflight-unreachable; {len(pairs)} remain.")
else:
    print("No preflight_unreachable.txt found; using all pairs.")

# Base options (no Android by default)
base_opts = {
    "outtmpl": str(raw_dir / "%(id)s.%(ext)s"),
    "format": "mp4/bestvideo+bestaudio/best",
    "merge_output_format": "mp4",
    "noprogress": True,
    "quiet": True,
    "geo_bypass": True,
}

# ---- NEW: use cookies only if present ----
cookiefile = root / "data" / "metadata" / "youtube_cookies.txt"
if cookiefile.exists():
    base_opts["cookiefile"] = str(cookiefile)
    print(f"Using YouTube cookies file: {cookiefile}")
else:
    print("No YouTube cookies file found; proceeding unauthenticated.")

# Try multiple yt client profiles (avoid Android PO token unless last resort)
yt_client_profiles = [
    {"youtube": {"player_client": ["web"]}},
    {"youtube": {"player_client": ["ios"]}},
    {"youtube": {"player_client": ["tvhtml5"]}},
    {"youtube": {"player_client": ["android"]}},  # last resort
]

def try_download_one(vid: str, url: str, retries=1) -> str:
    """Return 'ok' | 'skip' | 'fail'."""
    if (raw_dir / f"{vid}.mp4").exists():
        return "ok"

    # non-YouTube
    if not is_youtube(url):
        opts = dict(base_opts)
        netloc = urlparse(url).netloc.lower()
        if "aslsignbank.haskins.yale.edu" in netloc:
            opts["nocheckcertificate"] = True  # per-host only
        for _ in range(retries + 1):
            try:
                with YoutubeDL(opts) as ydl:
                    ydl.download([url])
                cand = list(raw_dir.glob(f"{vid}.*"))
                if cand:
                    ensure_mp4(cand[0])
                if (raw_dir / f"{vid}.mp4").exists():
                    return "ok"
            except Exception as e:
                msg = str(e).lower()
                if any(x in msg for x in ["404", "not found", "removed", "unavailable"]):
                    return "skip"
                sleep(1.0)
        return "fail"

    # YouTube
    for client_args in yt_client_profiles:
        opts = dict(base_opts)
        opts["extractor_args"] = {"youtube": client_args["youtube"]}
        try:
            with YoutubeDL(opts) as ydl:
                ydl.download([url])
            cand = list(raw_dir.glob(f"{vid}.*"))
            if cand:
                ensure_mp4(cand[0])
            if (raw_dir / f"{vid}.mp4").exists():
                return "ok"
        except Exception as e:
            msg = str(e).lower()
            unavailable = [
                "video unavailable", "private video", "copyright",
                "has been removed", "not available", "410", "403", "404"
            ]
            if any(x in msg for x in unavailable):
                return "skip"
            continue
    return "fail"

# Download loop: non-YouTube first
order = list(pairs.items())
non_yt = [(v,u) for v,u in order if not is_youtube(u)]
yt = [(v,u) for v,u in order if is_youtube(u)]
sequence = non_yt + yt

ok = 0; skipped = []; failed = []
for vid, url in tqdm(sequence, desc="Downloading"):
    status = try_download_one(vid, url)
    if status == "ok":
        ok += 1
    elif status == "skip":
        skipped.append(vid)
    else:
        failed.append(vid)

meta_dir = root / "data" / "metadata"
meta_dir.mkdir(parents=True, exist_ok=True)
with open(meta_dir / "skipped_unavailable.txt", "w") as f:
    f.write("\n".join(skipped))
with open(meta_dir / "missing.txt", "w") as f:
    f.write("\n".join(failed))

print(f"✅ OK: {ok}")
print(f"⚠️ Skipped (unavailable): {len(skipped)}  -> data/metadata/skipped_unavailable.txt")
print(f"❌ Failed (retry/request): {len(failed)}   -> data/metadata/missing.txt")
# Out:
# ffmpeg: /usr/bin/ffmpeg
# Filtered out 558 preflight-unreachable; 1480 remain.
# Using YouTube cookies file: /home/falasoul/notebooks/USD/AAI-590/Capstone/AAI-590-G3-ASL/data/metadata/youtube_cookies.txt
# Downloading:   0%|          | 0/1480 [00:00<?, ?it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   0%|          | 7/1480 [00:12<1:00:08,  2.45s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   1%|          | 8/1480 [00:12<47:09,  1.92s/it]  WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   1%|▏         | 20/1480 [00:22<20:39,  1.18it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   1%|▏         | 21/1480 [00:23<22:57,  1.06it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   1%|▏         | 22/1480 [00:24<23:17,  1.04it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   2%|▏         | 23/1480 [00:25<24:36,  1.01s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   2%|▏         | 24/1480 [00:26<23:47,  1.02it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   2%|▏         | 25/1480 [00:27<24:06,  1.01it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   2%|▏         | 29/1480 [00:30<19:17,  1.25it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   2%|▏         | 30/1480 [00:31<21:22,  1.13it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   2%|▏         | 31/1480 [00:32<22:44,  1.06it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   2%|▏         | 32/1480 [00:33<22:58,  1.05it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   3%|▎         | 44/1480 [00:42<20:24,  1.17it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   4%|▎         | 54/1480 [00:53<19:39,  1.21it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   4%|▎         | 55/1480 [00:54<19:43,  1.20it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   4%|▍         | 66/1480 [01:04<31:59,  1.36s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   5%|▍         | 67/1480 [01:05<28:20,  1.20s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   5%|▍         | 68/1480 [01:06<26:26,  1.12s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   5%|▍         | 69/1480 [01:07<24:31,  1.04s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   5%|▌         | 76/1480 [01:11<16:03,  1.46it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   5%|▌         | 77/1480 [01:12<18:55,  1.24it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   5%|▌         | 78/1480 [01:13<19:08,  1.22it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   5%|▌         | 79/1480 [01:14<20:16,  1.15it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# [download] Got error: HTTPSConnectionPool(host='www.signingsavvy.com', port=443): Read timed out. (read timeout=20.0)
# Downloading:   6%|▌         | 86/1480 [01:39<1:28:51,  3.82s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   6%|▋         | 95/1480 [01:46<20:03,  1.15it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   6%|▋         | 96/1480 [01:46<20:36,  1.12it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   7%|▋         | 97/1480 [01:47<20:56,  1.10it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   7%|▋         | 105/1480 [01:52<16:06,  1.42it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   8%|▊         | 112/1480 [02:06<59:32,  2.61s/it]  WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   8%|▊         | 122/1480 [06:27<20:21:58, 53.99s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   9%|▉         | 133/1480 [06:35<40:30,  1.80s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   9%|▉         | 134/1480 [06:36<35:15,  1.57s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   9%|▉         | 135/1480 [06:37<31:11,  1.39s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   9%|▉         | 136/1480 [06:38<28:42,  1.28s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:   9%|▉         | 137/1480 [06:39<26:12,  1.17s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  10%|▉         | 143/1480 [06:43<17:13,  1.29it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  10%|▉         | 144/1480 [06:44<17:49,  1.25it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  10%|█         | 150/1480 [06:48<17:32,  1.26it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  10%|█         | 152/1480 [06:50<18:47,  1.18it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  11%|█         | 158/1480 [07:14<2:28:05,  6.72s/it]ERROR: [generic] Unable to download webpage: HTTPSConnectionPool(host='media.asldeafined.com', port=443): Read timed out. (read timeout=20.0) (caused by TransportError("HTTPSConnectionPool(host='media.asldeafined.com', port=443): Read timed out. (read timeout=20.0)"))
# Downloading:  11%|█         | 159/1480 [07:36<4:06:30, 11.20s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  11%|█         | 166/1480 [07:41<32:32,  1.49s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  12%|█▏        | 175/1480 [08:00<35:18,  1.62s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  12%|█▏        | 183/1480 [08:07<20:08,  1.07it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  12%|█▏        | 184/1480 [08:08<19:47,  1.09it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  12%|█▎        | 185/1480 [08:09<20:26,  1.06it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  13%|█▎        | 186/1480 [08:10<20:58,  1.03it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  13%|█▎        | 190/1480 [08:12<12:49,  1.68it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  13%|█▎        | 194/1480 [08:15<16:07,  1.33it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  13%|█▎        | 195/1480 [08:16<17:39,  1.21it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  14%|█▎        | 203/1480 [08:25<30:09,  1.42s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  14%|█▍        | 204/1480 [08:26<26:43,  1.26s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  14%|█▍        | 205/1480 [08:27<24:59,  1.18s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  14%|█▍        | 213/1480 [08:35<23:30,  1.11s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  15%|█▍        | 221/1480 [08:41<18:25,  1.14it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  15%|█▌        | 222/1480 [08:42<19:35,  1.07it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  15%|█▌        | 229/1480 [08:48<18:20,  1.14it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  16%|█▌        | 230/1480 [08:49<18:59,  1.10it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  16%|█▌        | 236/1480 [08:55<25:17,  1.22s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  17%|█▋        | 246/1480 [09:04<21:24,  1.04s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  17%|█▋        | 250/1480 [09:06<14:09,  1.45it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  17%|█▋        | 258/1480 [09:13<15:45,  1.29it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  18%|█▊        | 267/1480 [09:21<29:32,  1.46s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  18%|█▊        | 268/1480 [09:22<25:56,  1.28s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  19%|█▊        | 274/1480 [09:25<13:38,  1.47it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  19%|█▊        | 277/1480 [09:28<15:36,  1.28it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  19%|█▉        | 278/1480 [09:29<17:08,  1.17it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  19%|█▉        | 285/1480 [09:35<17:22,  1.15it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  19%|█▉        | 286/1480 [09:35<17:23,  1.14it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  19%|█▉        | 287/1480 [09:36<17:41,  1.12it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  20%|██        | 297/1480 [09:46<15:04,  1.31it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  20%|██        | 299/1480 [09:48<15:58,  1.23it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  20%|██        | 300/1480 [09:49<16:54,  1.16it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  20%|██        | 301/1480 [09:50<17:09,  1.15it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  20%|██        | 302/1480 [09:51<17:28,  1.12it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  21%|██        | 311/1480 [10:01<29:52,  1.53s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# [download] Got error: 2332456 bytes read, 753835 more expected]ERROR:
# Downloading:  22%|██▏       | 326/1480 [14:06<1:55:17,  5.99s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  22%|██▏       | 327/1480 [14:07<1:25:49,  4.47s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  23%|██▎       | 336/1480 [18:07<11:11:51, 35.24s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  23%|██▎       | 342/1480 [18:11<1:30:58,  4.80s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  23%|██▎       | 343/1480 [18:12<1:08:36,  3.62s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  23%|██▎       | 344/1480 [18:13<53:20,  2.82s/it]  WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  24%|██▍       | 352/1480 [18:20<17:45,  1.06it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  24%|██▍       | 357/1480 [18:24<14:16,  1.31it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  24%|██▍       | 358/1480 [18:25<15:14,  1.23it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  25%|██▍       | 363/1480 [18:28<11:56,  1.56it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  25%|██▍       | 364/1480 [18:28<13:14,  1.40it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  25%|██▍       | 365/1480 [18:29<14:32,  1.28it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  25%|██▌       | 370/1480 [18:33<14:07,  1.31it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  25%|██▌       | 371/1480 [18:34<15:40,  1.18it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  25%|██▌       | 372/1480 [18:35<16:29,  1.12it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  25%|██▌       | 376/1480 [18:38<12:28,  1.48it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  26%|██▌       | 378/1480 [18:40<15:43,  1.17it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  26%|██▌       | 379/1480 [18:41<16:20,  1.12it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  26%|██▌       | 380/1480 [18:42<16:34,  1.11it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  26%|██▌       | 381/1480 [18:43<17:00,  1.08it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  26%|██▌       | 382/1480 [18:44<17:10,  1.07it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  26%|██▌       | 388/1480 [18:50<19:30,  1.07s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  26%|██▋       | 389/1480 [18:51<18:26,  1.01s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  27%|██▋       | 397/1480 [18:57<13:13,  1.36it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  27%|██▋       | 404/1480 [19:02<13:41,  1.31it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  28%|██▊       | 413/1480 [19:08<12:29,  1.42it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  28%|██▊       | 414/1480 [19:09<14:02,  1.26it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  28%|██▊       | 415/1480 [19:10<14:10,  1.25it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  28%|██▊       | 416/1480 [19:11<14:58,  1.18it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  29%|██▊       | 423/1480 [19:19<32:20,  1.84s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  29%|██▉       | 430/1480 [19:24<12:30,  1.40it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  30%|██▉       | 437/1480 [19:28<13:21,  1.30it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  30%|██▉       | 439/1480 [19:29<11:09,  1.56it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  30%|██▉       | 440/1480 [19:30<12:20,  1.41it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  30%|██▉       | 441/1480 [19:31<14:00,  1.24it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  30%|██▉       | 442/1480 [19:32<14:29,  1.19it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  31%|███       | 457/1480 [26:08<3:40:49, 12.95s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  31%|███       | 458/1480 [26:09<2:40:24,  9.42s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  32%|███▏      | 468/1480 [26:17<18:45,  1.11s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  32%|███▏      | 469/1480 [26:18<17:55,  1.06s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  32%|███▏      | 470/1480 [26:19<17:08,  1.02s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  32%|███▏      | 480/1480 [26:28<14:55,  1.12it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  33%|███▎      | 484/1480 [26:36<31:18,  1.89s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  33%|███▎      | 485/1480 [26:37<26:34,  1.60s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  33%|███▎      | 486/1480 [26:38<23:29,  1.42s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  33%|███▎      | 492/1480 [26:44<20:49,  1.26s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  33%|███▎      | 493/1480 [26:44<19:13,  1.17s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  34%|███▍      | 501/1480 [26:50<13:03,  1.25it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  34%|███▍      | 505/1480 [26:53<13:43,  1.18it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  34%|███▍      | 506/1480 [26:54<14:00,  1.16it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  35%|███▍      | 512/1480 [26:57<10:24,  1.55it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  35%|███▍      | 514/1480 [26:59<12:21,  1.30it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  36%|███▌      | 529/1480 [31:09<1:16:32,  4.83s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  36%|███▌      | 530/1480 [31:10<58:02,  3.67s/it]  WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  36%|███▌      | 531/1480 [31:11<44:46,  2.83s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  36%|███▌      | 535/1480 [31:14<19:52,  1.26s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  36%|███▋      | 537/1480 [31:20<33:48,  2.15s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  36%|███▋      | 538/1480 [31:21<28:01,  1.79s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  36%|███▋      | 539/1480 [31:21<23:28,  1.50s/it]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  37%|███▋      | 545/1480 [31:26<13:24,  1.16it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  37%|███▋      | 553/1480 [31:31<09:49,  1.57it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# Downloading:  37%|███▋      | 554/1480 [31:32<11:36,  1.33it/s]WARNING: [generic] Falling back on generic information extractor
# WARNING: [generic] URL could be a direct video link, returning it as such.
# WARNING: [generic] Falling back on generic information extractor
# ...
# Downloading:  98%|█████████▊| 1443/1480 [55:03<00:24,  1.51it/s]ERROR: [youtube] v_raVhhnAIE: Video unavailable
# Downloading:  98%|█████████▊| 1444/1480 [55:03<00:18,  1.93it/s]ERROR: [youtube] nsRQOdkyTP8: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Downloading:  98%|█████████▊| 1445/1480 [55:03<00:14,  2.41it/s]ERROR: [youtube] zfNH9EdhgNo: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  98%|█████████▊| 1446/1480 [55:04<00:17,  1.93it/s]ERROR: [youtube] zHd4YEFzpwE: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  98%|█████████▊| 1447/1480 [55:04<00:18,  1.83it/s]ERROR: [youtube] ESK6NAvvsKg: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  98%|█████████▊| 1448/1480 [55:05<00:18,  1.77it/s]ERROR: [youtube] nBhhhS7HXIo: Video unavailable
# Downloading:  98%|█████████▊| 1449/1480 [55:05<00:13,  2.24it/s]ERROR: [youtube] WprUBqi3iBc: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  98%|█████████▊| 1450/1480 [55:06<00:16,  1.86it/s]ERROR: [youtube] lKzYzA2JZaI: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  98%|█████████▊| 1451/1480 [55:07<00:17,  1.63it/s]ERROR: [youtube] zgdzYtHB6jg: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  98%|█████████▊| 1452/1480 [55:08<00:19,  1.47it/s]ERROR: [youtube] zW5FrLEDRiM: Video unavailable
# Downloading:  98%|█████████▊| 1453/1480 [55:08<00:14,  1.84it/s]ERROR: [youtube] 54csIWbS-Gc: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Downloading:  98%|█████████▊| 1454/1480 [55:08<00:11,  2.24it/s]ERROR: [youtube] e1RF5h4OgOg: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  98%|█████████▊| 1455/1480 [55:09<00:13,  1.88it/s]ERROR: [youtube] 0AbAh8gsQZg: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Downloading:  98%|█████████▊| 1456/1480 [55:09<00:10,  2.35it/s]ERROR: [youtube] bmc1BJWo_Pw: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Downloading:  98%|█████████▊| 1457/1480 [55:09<00:08,  2.82it/s]ERROR: [youtube] 5UnUWDYxfv0: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  99%|█████████▊| 1458/1480 [55:10<00:12,  1.74it/s]ERROR: [youtube] mxX9mVMl8O4: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  99%|█████████▊| 1459/1480 [55:11<00:12,  1.68it/s]ERROR: [youtube] rDAGt54vEsI: Video unavailable
# Downloading:  99%|█████████▊| 1460/1480 [55:11<00:09,  2.12it/s]ERROR: [youtube] BZxoTuwBHvA: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Downloading:  99%|█████████▊| 1461/1480 [55:11<00:07,  2.46it/s]ERROR: [youtube] sR_PzooQLx4: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Downloading:  99%|█████████▉| 1462/1480 [55:11<00:06,  3.00it/s]ERROR: [youtube] cnX45VWbjmc: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  99%|█████████▉| 1463/1480 [55:12<00:07,  2.19it/s]ERROR: [youtube] o1NMZAc7vO4: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  99%|█████████▉| 1464/1480 [55:13<00:08,  1.85it/s]ERROR: [youtube] OwtSP1QozuE: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  99%|█████████▉| 1465/1480 [55:14<00:10,  1.49it/s]ERROR: [youtube] XB3Q6IX6CBo: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  99%|█████████▉| 1466/1480 [55:15<00:08,  1.56it/s]ERROR: [youtube] Aq6l7fEWRVM: Video unavailable
# Downloading:  99%|█████████▉| 1467/1480 [55:15<00:07,  1.84it/s]ERROR: [youtube] bq-HmgjGzmw: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  99%|█████████▉| 1468/1480 [55:16<00:07,  1.69it/s]ERROR: [youtube] IRIy8xUFfHk: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  99%|█████████▉| 1469/1480 [55:16<00:07,  1.53it/s]ERROR: [youtube] JtgGFe8HIFQ: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  99%|█████████▉| 1470/1480 [55:17<00:07,  1.38it/s]ERROR: [youtube] rbEp5hFQljM: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Downloading:  99%|█████████▉| 1471/1480 [55:17<00:05,  1.75it/s]ERROR: [youtube] x6CehcknaH8: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading:  99%|█████████▉| 1472/1480 [55:18<00:04,  1.75it/s]ERROR: [youtube] giIzGcYftow: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Downloading: 100%|█████████▉| 1473/1480 [55:18<00:03,  2.16it/s]ERROR: [youtube] SvfopPYaJJU: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading: 100%|█████████▉| 1474/1480 [55:19<00:03,  1.77it/s]ERROR: [youtube] Uda6XJH18yw: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading: 100%|█████████▉| 1475/1480 [55:20<00:03,  1.55it/s]ERROR: [youtube] x6CehcknaH8: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading: 100%|█████████▉| 1476/1480 [55:21<00:02,  1.49it/s]ERROR: [youtube] sErq0TJMKEo: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading: 100%|█████████▉| 1477/1480 [55:21<00:02,  1.46it/s]ERROR: [youtube] avbqdo5HoQc: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading: 100%|█████████▉| 1478/1480 [55:22<00:01,  1.32it/s]ERROR: [youtube] PJs5VaRTMak: Video unavailable. This content isn't available, try again later. The current session has been rate-limited by YouTube for up to an hour. It is recommended to use `-t sleep` to add a delay between video requests to avoid exceeding the rate limit. For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#this-content-isnt-available-try-again-later
# Downloading: 100%|█████████▉| 1479/1480 [55:23<00:00,  1.21it/s]ERROR: [youtube] 3HztBiJlikY: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Downloading: 100%|██████████| 1480/1480 [55:23<00:00,  2.25s/it]
# ✅ OK: 7
# ⚠️ Skipped (unavailable): 611  -> data/metadata/skipped_unavailable.txt
# ❌ Failed (retry/request): 862   -> data/metadata/missing.txt
